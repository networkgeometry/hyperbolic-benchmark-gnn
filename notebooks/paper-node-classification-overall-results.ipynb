# %%
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import glob
import seaborn as sns
import sys
import copy
from tqdm.notebook import tqdm
from numba import jit
from scipy import stats
import networkx as nx
import re


import warnings
warnings.filterwarnings('ignore')

# %%
plt.rcParams["text.usetex"] = True
plt.rcParams['text.latex.preamble'] = r'\usepackage{amssymb,amsmath}'

plt.rcParams["figure.figsize"] = 11.7, 8.3
plt.rcParams["figure.dpi"] = 75

plt.rcParams["font.size"] = 28
plt.rcParams["font.family"] = "sans-serif"
plt.rcParams["font.sans-serif"] = ["Fira Sans", 'PT Sans', 'Open Sans', 'Roboto', 'DejaVu Sans', 'Liberation Sans', 'sans-serif']

plt.rcParams["legend.frameon"] = True
plt.rcParams["legend.fancybox"] = True
plt.rcParams["legend.fontsize"] = "small"

plt.rcParams["lines.linewidth"] = 2.5
plt.rcParams["lines.markersize"] = 14
plt.rcParams["lines.markeredgewidth"] = 2

plt.rcParams["xtick.major.size"] = 8
plt.rcParams["ytick.major.size"] = 8

# %%
df = pd.read_csv("../results/results_node_classification.csv")

df_sgformer = pd.read_csv("../results/sgformer_nc.csv")
df = pd.concat([df, df_sgformer])

df.head()
# Out:
#            model  with_features  nc_test_size  Beta_s  gamma_s  Ns_obs  \
# 0  GAT_Euclidean            1.0           0.7     1.1      2.1  5000.0
# 1  GAT_Euclidean            1.0           0.7     1.1      2.1  5000.0
# 2  GAT_Euclidean            1.0           0.7     1.1      2.1  5000.0
# 3  GAT_Euclidean            1.0           0.7     1.1      2.1  5000.0
# 4  GAT_Euclidean            1.0           0.7     1.1      2.1  5000.0
#
#    kmean_s  gamma_n  kmean_n  gamma_f     N_f  Beta_bi   nu  alpha  N_labels  \
# 0      3.0      2.1      3.0      2.1  2000.0      1.1  0.0   -1.0       2.0
# 1      3.0      2.1      3.0      2.1  2000.0      1.1  0.0   -1.0       3.0
# 2      3.0      2.1      3.0      2.1  2000.0      1.1  0.0   -1.0       6.0
# 3      3.0      2.1      3.0      2.1  2000.0      1.1  0.0   -1.0      10.0
# 4      3.0      2.1      3.0      2.1  2000.0      1.1  0.0    1.0       2.0
#
#     accuracy   i
# 0  63.171387 NaN
# 1  47.005000 NaN
# 2  24.591247 NaN
# ...

# %%
from statannotations.Annotator import Annotator

fix, ax = plt.subplots(figsize=(10, 12))

my_order = ['MLP_Euclidean', 'HNN_PoincareBall', 'GCN_Euclidean', 'GAT_Euclidean', 'HGCN_PoincareBall', 
            'SGFormer']

# Select pairs of models to compute the Mann-Whitney test
my_pairs = [
    (my_order[0], my_order[1]),
    (my_order[1], my_order[2]),
    (my_order[2], my_order[3]),
    (my_order[3], my_order[4]),
    (my_order[2], my_order[4]),
    (my_order[4], my_order[5]),
    (my_order[3], my_order[5]),
]

sns.boxplot(data=df, x='model', y='accuracy', order=my_order, palette="colorblind", linewidth=2,
           ax=ax)
ax.set_ylabel('Accuracy')
ax.set_xlabel('')
ax.set_xticks([0, 1, 2, 3, 4, 5], ['MLP', 'HNN', 'GCN', 'GAT', 'HGCN', 'SGFormer'])

annotator = Annotator(ax, my_pairs, data=df, x='model', y='accuracy', order=my_order, verbose=False)
annotator.configure(test='Mann-Whitney', text_format='star', loc='outside', 
                    text_offset=0, line_offset_to_group=0.01, verbose=2, line_height=0.02)
#loc='inside'
annotator.apply_test().annotate(line_offset_to_group=0.001, line_offset=0.001)

plt.tight_layout()
# plt.savefig("/home/rob/Dropbox/BenchmarkFeatures/Paper/IEEE Transaction on neural networks and learning systems/Second_Submission_IEEE/fig7_nc.pdf")
# Out:
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# MLP_Euclidean vs. HNN_PoincareBall: Mann-Whitney-Wilcoxon test two-sided, P_val:9.007e-01 U_stat=2.102e+06
# HNN_PoincareBall vs. GCN_Euclidean: Mann-Whitney-Wilcoxon test two-sided, P_val:3.487e-24 U_stat=1.713e+06
# GCN_Euclidean vs. GAT_Euclidean: Mann-Whitney-Wilcoxon test two-sided, P_val:7.943e-01 U_stat=2.087e+06
# GAT_Euclidean vs. HGCN_PoincareBall: Mann-Whitney-Wilcoxon test two-sided, P_val:2.257e-01 U_stat=2.143e+06
# HGCN_PoincareBall vs. SGFormer: Mann-Whitney-Wilcoxon test two-sided, P_val:3.438e-04 U_stat=1.962e+06
# GCN_Euclidean vs. HGCN_PoincareBall: Mann-Whitney-Wilcoxon test two-sided, P_val:3.480e-01 U_stat=2.133e+06
# GAT_Euclidean vs. SGFormer: Mann-Whitney-Wilcoxon test two-sided, P_val:1.464e-02 U_stat=2.005e+06
